# %%
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

# %%
from crewai import LLM

llm = LLM(
    model="gemini/gemini-2.5-flash",
    api_key="AIzaSyCOQTOwCxxWQIi-Q__dXJQ8qbDSl2lUOqY"
)

# %%
llm.call("tell me about AI in 2 lines")
# Out:
# 'AI empowers machines to simulate human intelligence.\nThey learn, reason, and solve problems by processing data.'

# %%
llm.get_token_usage_summary()
# Out:
# UsageMetrics(total_tokens=30, prompt_tokens=9, cached_prompt_tokens=0, completion_tokens=21, successful_requests=1)
